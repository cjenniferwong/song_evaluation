# %%
import pandas as pd

import pickle
import spotipy
import spotipy.util as util
import json

# %%
missing = pd.read_csv('../data/missing_data_songs.csv')
missing.head()
# Out:
#    artists  duration_ms  explicit  id  name  popularity  \
# 0      NaN          NaN       NaN NaN   NaN         NaN
# 1      NaN          NaN       NaN NaN   NaN         NaN
# 2      NaN          NaN       NaN NaN   NaN         NaN
# 3      NaN          NaN       NaN NaN   NaN         NaN
# 4      NaN          NaN       NaN NaN   NaN         NaN
#
#              modified_query                              search_query  \
# 0          quavo good drank  2 chainz x gucci mane x quavo good drank
# 1       21 savage my choppa           21 savage my choppa hate n****s
# 2            becky g pijama        becky g + natti natasha sin pijama
# 3  brett wanna be that song         brett eldredge wanna be that song
# 4    jayz caught their eyes                   jay-z caught their eyes
#
#    acousticness  danceability  ...  duration  end_of_fade_in  key_confidence  \
# 0           NaN           NaN  ...       NaN             NaN             NaN
# ...
